# %% [markdown]
# <a href="https://colab.research.google.com/github/anjali481/summer_of_bitcoin_task/blob/main/Summer_of_bitcoin.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
dataframe=pd.read_csv("mempool.csv")

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5214 entries, 0 to 5213
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   tx_id     5214 non-null   object
#  1   fee       5214 non-null   int64
#  2   weight    5214 non-null   int64
#  3   parents   2000 non-null   object
# dtypes: int64(2), object(2)
# memory usage: 163.1+ KB

# %%
dataframe.head(50)
# Out:
#                                                 tx_id  ...                                           parents
# 0   2e3da8fbc1eaca8ed9b7c2db9e6545d8ccac3c67deadee...  ...                                                NaN
# 1   79c51c9d4124c5cbb37a85263748dcf44e182dff83561f...  ...  6eb38fad135e38a93cb47a15a5f953cbc0563fd84bf1ab...
# 2   b0ef627c8dc2a706475d33d7712209ec779f7a8302aaea...  ...                                                NaN
# 3   8c25f9be93990b96e8bc363778d6debee6867c7d73cefa...  ...                                                NaN
# 4   edc82751537be6afcb21c0229d8d20916d8e742a363ab2...  ...                                                NaN
# 5   384718a612cc6b220a8eeaf36f9d179e70fe233e2e9068...  ...  edc82751537be6afcb21c0229d8d20916d8e742a363ab2...
# 6   d506243d15088e94cf5300c55c67889d61f798750f6c59...  ...                                                NaN
# ...

# %%
df = dataframe.sort_values(['fee','weight'], ascending=[False, True]).reset_index(drop=True)

# %%
df.head(12)
# Out:
#                                                 tx_id     fee  weight parents
# 0   59f0495cf66d1864359dda816eb7189b9d9a3a9cd9dc50...  201700    1348      NaN
# 1   3bfc4c22fc7aaded4b02c6a6d67b4a7bad297377e46e4c...  194166    3852      NaN
# 2   87784075804f10dad1f815de867dde2875e73a13da798c...  107775    1660      NaN
# 3   0c8ebf9c75f63b7e5ff176e2937f24c694aa6b3bde0e59...  104400    2084      NaN
# 4   c3fef085fca34891e6456489d840ab68139b24857eb1f9...  100000    1148      NaN
# 5   826c80c43044cc00bebdf021a42dca6946591f02710e4e...   90000     896      NaN
# 6   2a75876d05905369cda2997032a66e0a0f12253aa5736a...   74544  295164      NaN
# 7   6a709ddadfcf13b2e302cf0f75163538b0273923cc55fc...   59326    1364      NaN
# 8   de669dad7f8d8b37a789cb8f86ddd62b93b7b8323d90ff...   57000     756      NaN
# 9   b8894fbe99628c253fa93cf178679727e117d04fea5e50...   54675     904      NaN
# 10  8de07b4f7af6f61dfb0ac878ba45bd7b8b7184a1376e52...   50000    4436      NaN
# ...

# %%
def isvalidweight(x):
    if minweight + x['weight'] <= highest_weight:
        return True
    else:
        return False


def list_check(x):
    if str(x) in final_set_of_txids:
        return True
    else:
        return False

def parent(x):
    if str(x[3]) != "nan":
        parent_list = str(x[3]).split(";")
        for i in parent_list:
            if(check_list(i)):
                continue
            else:
                txnindex = df[df['tx_id'] == i].index.item()
                k = df.loc[txnindex]
                trans_add(k)

def add_tran(x):
    global minweight
    txnID = x[0]
    weight = x[2]
    minweight += weight
    transaction_total_list.append(txnID)

def trans_add(x):
    if(check_weight(x)):
        if(not list_check(x)):
            parent(x)
            if(isvalidweight(x)):
                add_tran(x)


def start(df):
   
    for i in range(len(df)):
        txnVar =  df.loc[i]
        trans_add(txnVar)


def write(list_tr):
    file = open("block.txt","a")
    for i in list_tr:
        file.write(str(i) + '\n')
    file.close()

# %%
highest_weight = 4000000
minweight = 0
transaction_total_list= []


start(df)

write(transaction_total_list)

# %%
transaction_total_list
# Out:
# ['59f0495cf66d1864359dda816eb7189b9d9a3a9cd9dc50a3707776b41a6c815b',
#  '3bfc4c22fc7aaded4b02c6a6d67b4a7bad297377e46e4c300208f3bc3d65aae1',
#  '87784075804f10dad1f815de867dde2875e73a13da798c317fcddd75e03efc95',
#  '0c8ebf9c75f63b7e5ff176e2937f24c694aa6b3bde0e59b5647983bbb7dd38d6',
#  'c3fef085fca34891e6456489d840ab68139b24857eb1f925b943066ebb988732',
#  '826c80c43044cc00bebdf021a42dca6946591f02710e4e6da58c094be8e62d00',
#  '2a75876d05905369cda2997032a66e0a0f12253aa5736a23c005d26b22983c1a',
#  '6a709ddadfcf13b2e302cf0f75163538b0273923cc55fccc158f7466abebc1a9',
#  'de669dad7f8d8b37a789cb8f86ddd62b93b7b8323d90ff29fa61ca1f41f8c73f',
#  'b8894fbe99628c253fa93cf178679727e117d04fea5e5079de002548a0dd6511',
#  '8de07b4f7af6f61dfb0ac878ba45bd7b8b7184a1376e5286c90cd983679447f5',
#  'fac0417aafa46ea002ed3e04fc38087b45aca6a15a47bd4e5026e1e6cefa7967',
#  'f3c2f6cb4573cf137178f355af9301f3c0dbebf23c172804a894a7e4f899c110',
#  '7f264c468f624b62071dbcb531de5af722b327d5b098f426314622340cf17512',
# ...

# %%
# Out:
# []
